# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import precision_recall_curve, average_precision_score
from tensorflow.keras.regularizers import l2
# ==== 1. Tên lớp gộp ====
class_names = [
    'benign', 'bruteforce', 'dos', 'ftp', 'reconnaissance',
    'reverse_shell', 'smtp', 'sql_injection', 'ssh', 'ssrf', 'xss'
]

# ==== 2. Hàm reshape an toàn ====
def safe_reshape(X, n_features=63):
    if len(X.shape) == 1:
        assert X.size % n_features == 0, "Tổng phần tử không chia hết cho số đặc trưng"
        X = X.reshape(-1, n_features)
    elif X.shape[1] != n_features:
        raise ValueError(f"Số đặc trưng không đúng. Mong đợi {n_features}, nhưng nhận được {X.shape[1]}")
    return X.reshape(-1, n_features, 1)

# ==== 3. Load và xử lý dữ liệu ====
def load_data(data_path):
    X_train = np.load(os.path.join(data_path, 'X_train.npy'))
    y_train = np.load(os.path.join(data_path, 'y_train.npy'))
    X_val   = np.load(os.path.join(data_path, 'X_val.npy'))
    y_val   = np.load(os.path.join(data_path, 'y_val.npy'))
    X_test  = np.load(os.path.join(data_path, 'X_test.npy'))
    y_test  = np.load(os.path.join(data_path, 'y_test.npy'))

    X_train = safe_reshape(X_train, n_features=35)
    X_val   = safe_reshape(X_val, n_features=35)
    X_test  = safe_reshape(X_test, n_features=35)
    print("Phân bố lớp:", np.sum(y_train, axis=0))
    return X_train, y_train, X_val, y_val, X_test, y_test

# ==== Xây dựng mô hình CNN ====
def build_cnn_model(input_shape=(35, 1), num_classes=11):
    model = Sequential()
    model.add(Conv1D(32, kernel_size=3, activation='relu', padding='same', input_shape=input_shape, 
                    kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))

    model.add(Conv1D(128, kernel_size=3, activation='relu', padding='same', 
                    kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))

    model.add(Conv1D(256, kernel_size=3, activation='relu', padding='same', 
                    kernel_regularizer=l2(0.001)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))

    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.001)))
    model.add(Dropout(0.3))
    model.add(Dense(num_classes, activation='softmax'))

    model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# ==== 5. Biểu đồ training ====
def plot_history(history):
    plt.figure(figsize=(14, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Loss over Epochs')
    plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Acc')
    plt.plot(history.history['val_accuracy'], label='Val Acc')
    plt.title('Accuracy over Epochs')
    plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend()

    plt.tight_layout()
    plt.show()

# ==== 6. Ma trận nhầm lẫn ====
def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)
    
    # Chuyển thành tỷ lệ phần trăm theo hàng (theo từng lớp thực)
    cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    cm_percent = np.round(cm_percent * 100, 2)  # nhân 100 và làm tròn

    plt.figure(figsize=(10, 8))
    sns.heatmap(cm_percent, annot=True, fmt='.2f', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)

    plt.xlabel('Dự đoán')
    plt.ylabel('Thực tế')
    plt.title('Ma Trận Nhầm lẫn')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()


# ==== 7. Precision-Recall ==== 
def plot_precision_recall(y_true_onehot, y_pred_probs, class_names):
    precision, recall, ap_score = dict(), dict(), dict()
    n_classes = y_true_onehot.shape[1]

    plt.figure(figsize=(10, 8))
    for i in range(n_classes):
        precision[i], recall[i], _ = precision_recall_curve(y_true_onehot[:, i], y_pred_probs[:, i])
        ap_score[i] = average_precision_score(y_true_onehot[:, i], y_pred_probs[:, i])
        plt.plot(recall[i], precision[i], 
                 label=f"{class_names[i]} (AP = {ap_score[i]:.2f})")

    # Micro-average (tổng hợp toàn bộ)
    precision_micro, recall_micro, _ = precision_recall_curve(y_true_onehot.ravel(), y_pred_probs.ravel())
    ap_micro = average_precision_score(y_true_onehot, y_pred_probs, average="micro")
    plt.plot(recall_micro, precision_micro,
             label=f"Micro-average (AP = {ap_micro:.2f})", color='black', linestyle='--')

    plt.title("Precision-Recall Curves for All Classes")
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.legend(loc="lower left")
    plt.grid()
    plt.show()

# ==== 8. Main pipeline ====
def main():
    data_path = r'D:/webids23_processed1/'
    print("🔄 Đang load dữ liệu...")
    X_train, y_train, X_val, y_val, X_test, y_test = load_data(data_path)

    print("✅ Dữ liệu đã được load. Bắt đầu xây dựng mô hình CNN...")
    model = build_cnn_model()

    callbacks = [
        EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)
    ]
    model.summary()
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=300,
        batch_size=128,
        callbacks=callbacks,
        verbose=1
    )

    print("✅ Huấn luyện xong. Hiển thị biểu đồ...")
    plot_history(history)

    print("🔎 Dự đoán trên tập test...")
    y_pred_probs = model.predict(X_test)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test, axis=1)

    print("📊 Ma trận nhầm lẫn:")
    plot_confusion_matrix(y_true, y_pred, class_names)

    print("\n📋 Classification Report:")
    print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

    print("\n📈 Precision-Recall từng lớp:")
    plot_precision_recall(y_test, y_pred_probs, class_names)
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
    print(f"\n✅ Test Accuracy: {test_acc:.4f} - Test Loss: {test_loss:.4f}")

    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
    print(f"\n✅ Test Accuracy: {test_acc:.4f} - Test Loss: {test_loss:.4f}")

    model.save("cnn_webids23_model.h5")
    print("💾 Mô hình đã được lưu vào: cnn_webids23_model.h5")

# ==== 9. Chạy chương trình ====
if __name__ == "__main__":
    main()
# Out:
# 🔄 Đang load dữ liệu...
# Phân bố lớp: [14000. 14000. 14000. 14000. 14000. 14000. 13999. 14000. 14000. 14000.
#  14000.]
# ✅ Dữ liệu đã được load. Bắt đầu xây dựng mô hình CNN...
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 35, 32)            128
#
#  batch_normalization_3 (Batc  (None, 35, 32)           128
#  hNormalization)
#
#  max_pooling1d_3 (MaxPooling  (None, 18, 32)           0
#  1D)
#
#  conv1d_4 (Conv1D)           (None, 18, 128)           12416
#
#  batch_normalization_4 (Batc  (None, 18, 128)          512
#  hNormalization)
#
#  max_pooling1d_4 (MaxPooling  (None, 9, 128)           0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 9, 256)            98560
#
#  batch_normalization_5 (Batc  (None, 9, 256)           1024
#  hNormalization)
#
#  max_pooling1d_5 (MaxPooling  (None, 5, 256)           0
#  1D)
#
#  flatten_1 (Flatten)         (None, 1280)              0
#
#  dense_2 (Dense)             (None, 128)               163968
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 11)                1419
#
# =================================================================
# Total params: 278,155
# Trainable params: 277,323
# Non-trainable params: 832
# _________________________________________________________________
# Epoch 1/300
# 1204/1204 [==============================] - 13s 9ms/step - loss: 1.5646 - accuracy: 0.5912 - val_loss: 1.2096 - val_accuracy: 0.6923 - lr: 1.0000e-04
# Epoch 2/300
# 1204/1204 [==============================] - 10s 8ms/step - loss: 1.1043 - accuracy: 0.7261 - val_loss: 1.1222 - val_accuracy: 0.6780 - lr: 1.0000e-04
# Epoch 3/300
# 1204/1204 [==============================] - 10s 8ms/step - loss: 0.9154 - accuracy: 0.7809 - val_loss: 0.8331 - val_accuracy: 0.8564 - lr: 1.0000e-04
# Epoch 4/300
# 1204/1204 [==============================] - 10s 8ms/step - loss: 0.7953 - accuracy: 0.8168 - val_loss: 0.7250 - val_accuracy: 0.8273 - lr: 1.0000e-04
# Epoch 5/300
# 1204/1204 [==============================] - 10s 8ms/step - loss: 0.7054 - accuracy: 0.8439 - val_loss: 0.6403 - val_accuracy: 0.8318 - lr: 1.0000e-04
# Epoch 6/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.6365 - accuracy: 0.8650 - val_loss: 0.5751 - val_accuracy: 0.8486 - lr: 1.0000e-04
# Epoch 7/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.5791 - accuracy: 0.8791 - val_loss: 0.6223 - val_accuracy: 0.8385 - lr: 1.0000e-04
# Epoch 8/300
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.5252 - accuracy: 0.8910 - val_loss: 0.4725 - val_accuracy: 0.9030 - lr: 1.0000e-04
# Epoch 9/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.4904 - accuracy: 0.8956 - val_loss: 0.4800 - val_accuracy: 0.9022 - lr: 1.0000e-04
# Epoch 10/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.4579 - accuracy: 0.9020 - val_loss: 0.5665 - val_accuracy: 0.8261 - lr: 1.0000e-04
# Epoch 11/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.4431 - accuracy: 0.9010 - val_loss: 0.4651 - val_accuracy: 0.8487 - lr: 1.0000e-04
# Epoch 12/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.4188 - accuracy: 0.9053 - val_loss: 0.3922 - val_accuracy: 0.9094 - lr: 1.0000e-04
# Epoch 13/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.4032 - accuracy: 0.9073 - val_loss: 0.3922 - val_accuracy: 0.9099 - lr: 1.0000e-04
# Epoch 14/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.3870 - accuracy: 0.9088 - val_loss: 0.3905 - val_accuracy: 0.9014 - lr: 1.0000e-04
# Epoch 15/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.3754 - accuracy: 0.9096 - val_loss: 0.3914 - val_accuracy: 0.9000 - lr: 1.0000e-04
# Epoch 16/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.3636 - accuracy: 0.9111 - val_loss: 0.3914 - val_accuracy: 0.8954 - lr: 1.0000e-04
# Epoch 17/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.3550 - accuracy: 0.9111 - val_loss: 0.3366 - val_accuracy: 0.9174 - lr: 1.0000e-04
# Epoch 18/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.3423 - accuracy: 0.9133 - val_loss: 0.3300 - val_accuracy: 0.9083 - lr: 1.0000e-04
# Epoch 19/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.3348 - accuracy: 0.9135 - val_loss: 0.5583 - val_accuracy: 0.8625 - lr: 1.0000e-04
# Epoch 20/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.3279 - accuracy: 0.9146 - val_loss: 0.3257 - val_accuracy: 0.9143 - lr: 1.0000e-04
# Epoch 21/300
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.3196 - accuracy: 0.9150 - val_loss: 0.3754 - val_accuracy: 0.9054 - lr: 1.0000e-04
# Epoch 22/300
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.3134 - accuracy: 0.9163 - val_loss: 0.4053 - val_accuracy: 0.8673 - lr: 1.0000e-04
# Epoch 23/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.3076 - accuracy: 0.9160 - val_loss: 0.4163 - val_accuracy: 0.8568 - lr: 1.0000e-04
# Epoch 24/300
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.3008 - accuracy: 0.9175 - val_loss: 0.3170 - val_accuracy: 0.9159 - lr: 1.0000e-04
# Epoch 25/300
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2944 - accuracy: 0.9184 - val_loss: 0.3778 - val_accuracy: 0.8907 - lr: 1.0000e-04
# Epoch 26/300
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2889 - accuracy: 0.9201 - val_loss: 0.3740 - val_accuracy: 0.8641 - lr: 1.0000e-04
# Epoch 27/300
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2824 - accuracy: 0.9213 - val_loss: 0.3126 - val_accuracy: 0.9015 - lr: 1.0000e-04
# Epoch 28/300
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2752 - accuracy: 0.9234 - val_loss: 0.2793 - val_accuracy: 0.9186 - lr: 1.0000e-04
# Epoch 29/300
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2716 - accuracy: 0.9243 - val_loss: 0.4303 - val_accuracy: 0.8613 - lr: 1.0000e-04
# Epoch 30/300
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.2659 - accuracy: 0.9259 - val_loss: 0.4579 - val_accuracy: 0.8744 - lr: 1.0000e-04
# Epoch 31/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2613 - accuracy: 0.9266 - val_loss: 1.1587 - val_accuracy: 0.7748 - lr: 1.0000e-04
# Epoch 32/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2565 - accuracy: 0.9285 - val_loss: 0.2488 - val_accuracy: 0.9312 - lr: 1.0000e-04
# Epoch 33/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2517 - accuracy: 0.9290 - val_loss: 0.3647 - val_accuracy: 0.8869 - lr: 1.0000e-04
# Epoch 34/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2516 - accuracy: 0.9283 - val_loss: 0.4252 - val_accuracy: 0.8151 - lr: 1.0000e-04
# Epoch 35/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2471 - accuracy: 0.9298 - val_loss: 0.7096 - val_accuracy: 0.8233 - lr: 1.0000e-04
# Epoch 36/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.2451 - accuracy: 0.9303 - val_loss: 0.2735 - val_accuracy: 0.9219 - lr: 1.0000e-04
# Epoch 37/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.2409 - accuracy: 0.9314 - val_loss: 0.2799 - val_accuracy: 0.9160 - lr: 1.0000e-04
# Epoch 38/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.2303 - accuracy: 0.9343 - val_loss: 0.7264 - val_accuracy: 0.8011 - lr: 5.0000e-05
# Epoch 39/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2273 - accuracy: 0.9349 - val_loss: 0.2259 - val_accuracy: 0.9355 - lr: 5.0000e-05
# Epoch 40/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2265 - accuracy: 0.9346 - val_loss: 0.2189 - val_accuracy: 0.9370 - lr: 5.0000e-05
# Epoch 41/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2247 - accuracy: 0.9348 - val_loss: 0.2693 - val_accuracy: 0.9108 - lr: 5.0000e-05
# Epoch 42/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2223 - accuracy: 0.9353 - val_loss: 0.2587 - val_accuracy: 0.9210 - lr: 5.0000e-05
# Epoch 43/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2232 - accuracy: 0.9347 - val_loss: 0.2298 - val_accuracy: 0.9381 - lr: 5.0000e-05
# Epoch 44/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2201 - accuracy: 0.9357 - val_loss: 0.2614 - val_accuracy: 0.8945 - lr: 5.0000e-05
# Epoch 45/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2205 - accuracy: 0.9350 - val_loss: 0.2524 - val_accuracy: 0.9298 - lr: 5.0000e-05
# Epoch 46/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2141 - accuracy: 0.9369 - val_loss: 0.2178 - val_accuracy: 0.9373 - lr: 2.5000e-05
# Epoch 47/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2130 - accuracy: 0.9372 - val_loss: 0.2241 - val_accuracy: 0.9357 - lr: 2.5000e-05
# Epoch 48/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2123 - accuracy: 0.9372 - val_loss: 0.2182 - val_accuracy: 0.9379 - lr: 2.5000e-05
# Epoch 49/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2120 - accuracy: 0.9376 - val_loss: 0.2219 - val_accuracy: 0.9337 - lr: 2.5000e-05
# Epoch 50/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2106 - accuracy: 0.9377 - val_loss: 0.2440 - val_accuracy: 0.9263 - lr: 2.5000e-05
# Epoch 51/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2106 - accuracy: 0.9377 - val_loss: 0.2136 - val_accuracy: 0.9376 - lr: 2.5000e-05
# Epoch 52/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2099 - accuracy: 0.9376 - val_loss: 0.2349 - val_accuracy: 0.9234 - lr: 2.5000e-05
# Epoch 53/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2096 - accuracy: 0.9375 - val_loss: 0.2586 - val_accuracy: 0.9257 - lr: 2.5000e-05
# Epoch 54/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2092 - accuracy: 0.9371 - val_loss: 0.2210 - val_accuracy: 0.9300 - lr: 2.5000e-05
# Epoch 55/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2083 - accuracy: 0.9375 - val_loss: 0.2050 - val_accuracy: 0.9405 - lr: 2.5000e-05
# Epoch 56/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2074 - accuracy: 0.9379 - val_loss: 0.2211 - val_accuracy: 0.9278 - lr: 2.5000e-05
# Epoch 57/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2074 - accuracy: 0.9381 - val_loss: 0.2536 - val_accuracy: 0.9249 - lr: 2.5000e-05
# Epoch 58/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2077 - accuracy: 0.9380 - val_loss: 0.3497 - val_accuracy: 0.8603 - lr: 2.5000e-05
# Epoch 59/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2060 - accuracy: 0.9386 - val_loss: 0.2066 - val_accuracy: 0.9377 - lr: 2.5000e-05
# Epoch 60/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2059 - accuracy: 0.9380 - val_loss: 0.2198 - val_accuracy: 0.9313 - lr: 2.5000e-05
# Epoch 61/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2030 - accuracy: 0.9388 - val_loss: 0.2049 - val_accuracy: 0.9405 - lr: 1.2500e-05
# Epoch 62/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2028 - accuracy: 0.9388 - val_loss: 0.2002 - val_accuracy: 0.9417 - lr: 1.2500e-05
# Epoch 63/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2020 - accuracy: 0.9392 - val_loss: 0.2041 - val_accuracy: 0.9369 - lr: 1.2500e-05
# Epoch 64/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2015 - accuracy: 0.9388 - val_loss: 0.2044 - val_accuracy: 0.9400 - lr: 1.2500e-05
# Epoch 65/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.2018 - accuracy: 0.9395 - val_loss: 0.2007 - val_accuracy: 0.9415 - lr: 1.2500e-05
# Epoch 66/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.2016 - accuracy: 0.9393 - val_loss: 0.2121 - val_accuracy: 0.9372 - lr: 1.2500e-05
# Epoch 67/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.2008 - accuracy: 0.9395 - val_loss: 0.2215 - val_accuracy: 0.9410 - lr: 1.2500e-05
# Epoch 68/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1993 - accuracy: 0.9399 - val_loss: 0.2014 - val_accuracy: 0.9400 - lr: 6.2500e-06
# Epoch 69/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1994 - accuracy: 0.9400 - val_loss: 0.1977 - val_accuracy: 0.9407 - lr: 6.2500e-06
# Epoch 70/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1988 - accuracy: 0.9399 - val_loss: 0.2065 - val_accuracy: 0.9405 - lr: 6.2500e-06
# Epoch 71/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1989 - accuracy: 0.9397 - val_loss: 0.2012 - val_accuracy: 0.9414 - lr: 6.2500e-06
# Epoch 72/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1985 - accuracy: 0.9398 - val_loss: 0.1967 - val_accuracy: 0.9416 - lr: 6.2500e-06
# Epoch 73/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1986 - accuracy: 0.9402 - val_loss: 0.1971 - val_accuracy: 0.9420 - lr: 6.2500e-06
# Epoch 74/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1982 - accuracy: 0.9402 - val_loss: 0.1978 - val_accuracy: 0.9395 - lr: 6.2500e-06
# Epoch 75/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1982 - accuracy: 0.9400 - val_loss: 0.2045 - val_accuracy: 0.9378 - lr: 6.2500e-06
# Epoch 76/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1986 - accuracy: 0.9404 - val_loss: 0.1970 - val_accuracy: 0.9387 - lr: 6.2500e-06
# Epoch 77/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1980 - accuracy: 0.9400 - val_loss: 0.1952 - val_accuracy: 0.9416 - lr: 6.2500e-06
# Epoch 78/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1981 - accuracy: 0.9403 - val_loss: 0.1976 - val_accuracy: 0.9399 - lr: 6.2500e-06
# Epoch 79/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1977 - accuracy: 0.9403 - val_loss: 0.1995 - val_accuracy: 0.9404 - lr: 6.2500e-06
# Epoch 80/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1975 - accuracy: 0.9398 - val_loss: 0.1953 - val_accuracy: 0.9416 - lr: 6.2500e-06
# Epoch 81/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1976 - accuracy: 0.9398 - val_loss: 0.1980 - val_accuracy: 0.9411 - lr: 6.2500e-06
# Epoch 82/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1973 - accuracy: 0.9401 - val_loss: 0.1988 - val_accuracy: 0.9415 - lr: 6.2500e-06
# Epoch 83/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1967 - accuracy: 0.9405 - val_loss: 0.1948 - val_accuracy: 0.9419 - lr: 3.1250e-06
# Epoch 84/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1966 - accuracy: 0.9404 - val_loss: 0.1942 - val_accuracy: 0.9423 - lr: 3.1250e-06
# Epoch 85/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1961 - accuracy: 0.9406 - val_loss: 0.1974 - val_accuracy: 0.9405 - lr: 3.1250e-06
# Epoch 86/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1960 - accuracy: 0.9405 - val_loss: 0.1939 - val_accuracy: 0.9415 - lr: 3.1250e-06
# Epoch 87/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1964 - accuracy: 0.9404 - val_loss: 0.1945 - val_accuracy: 0.9421 - lr: 3.1250e-06
# Epoch 88/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1961 - accuracy: 0.9405 - val_loss: 0.1941 - val_accuracy: 0.9419 - lr: 3.1250e-06
# Epoch 89/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1957 - accuracy: 0.9404 - val_loss: 0.1941 - val_accuracy: 0.9428 - lr: 3.1250e-06
# Epoch 90/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1958 - accuracy: 0.9405 - val_loss: 0.1940 - val_accuracy: 0.9416 - lr: 3.1250e-06
# Epoch 91/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1961 - accuracy: 0.9405 - val_loss: 0.1948 - val_accuracy: 0.9408 - lr: 3.1250e-06
# Epoch 92/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1952 - accuracy: 0.9409 - val_loss: 0.1949 - val_accuracy: 0.9405 - lr: 1.5625e-06
# Epoch 93/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1957 - accuracy: 0.9410 - val_loss: 0.1937 - val_accuracy: 0.9420 - lr: 1.5625e-06
# Epoch 94/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1955 - accuracy: 0.9406 - val_loss: 0.1936 - val_accuracy: 0.9417 - lr: 1.5625e-06
# Epoch 95/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1952 - accuracy: 0.9406 - val_loss: 0.1957 - val_accuracy: 0.9407 - lr: 1.5625e-06
# Epoch 96/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1953 - accuracy: 0.9407 - val_loss: 0.1934 - val_accuracy: 0.9425 - lr: 1.5625e-06
# Epoch 97/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1954 - accuracy: 0.9409 - val_loss: 0.1932 - val_accuracy: 0.9416 - lr: 1.5625e-06
# Epoch 98/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1953 - accuracy: 0.9406 - val_loss: 0.1933 - val_accuracy: 0.9415 - lr: 1.5625e-06
# Epoch 99/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1951 - accuracy: 0.9405 - val_loss: 0.1944 - val_accuracy: 0.9422 - lr: 1.5625e-06
# Epoch 100/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1948 - accuracy: 0.9410 - val_loss: 0.1931 - val_accuracy: 0.9423 - lr: 1.5625e-06
# Epoch 101/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1950 - accuracy: 0.9406 - val_loss: 0.1929 - val_accuracy: 0.9421 - lr: 1.5625e-06
# Epoch 102/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1952 - accuracy: 0.9407 - val_loss: 0.1934 - val_accuracy: 0.9406 - lr: 1.5625e-06
# Epoch 103/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1949 - accuracy: 0.9408 - val_loss: 0.1933 - val_accuracy: 0.9421 - lr: 1.5625e-06
# Epoch 104/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1948 - accuracy: 0.9408 - val_loss: 0.1931 - val_accuracy: 0.9423 - lr: 1.5625e-06
# Epoch 105/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1952 - accuracy: 0.9410 - val_loss: 0.1929 - val_accuracy: 0.9422 - lr: 1.5625e-06
# Epoch 106/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1945 - accuracy: 0.9407 - val_loss: 0.1928 - val_accuracy: 0.9423 - lr: 1.5625e-06
# Epoch 107/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1947 - accuracy: 0.9408 - val_loss: 0.1928 - val_accuracy: 0.9424 - lr: 7.8125e-07
# Epoch 108/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1947 - accuracy: 0.9408 - val_loss: 0.1930 - val_accuracy: 0.9420 - lr: 7.8125e-07
# Epoch 109/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1941 - accuracy: 0.9413 - val_loss: 0.1930 - val_accuracy: 0.9424 - lr: 7.8125e-07
# Epoch 110/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1946 - accuracy: 0.9411 - val_loss: 0.1927 - val_accuracy: 0.9419 - lr: 7.8125e-07
# Epoch 111/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1949 - accuracy: 0.9408 - val_loss: 0.1927 - val_accuracy: 0.9418 - lr: 7.8125e-07
# Epoch 112/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1946 - accuracy: 0.9406 - val_loss: 0.1935 - val_accuracy: 0.9414 - lr: 7.8125e-07
# Epoch 113/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1943 - accuracy: 0.9410 - val_loss: 0.1926 - val_accuracy: 0.9422 - lr: 3.9062e-07
# Epoch 114/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1943 - accuracy: 0.9407 - val_loss: 0.1928 - val_accuracy: 0.9423 - lr: 3.9062e-07
# Epoch 115/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1943 - accuracy: 0.9407 - val_loss: 0.1927 - val_accuracy: 0.9420 - lr: 3.9062e-07
# Epoch 116/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1945 - accuracy: 0.9409 - val_loss: 0.1926 - val_accuracy: 0.9420 - lr: 3.9062e-07
# Epoch 117/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1943 - accuracy: 0.9417 - val_loss: 0.1927 - val_accuracy: 0.9421 - lr: 3.9062e-07
# Epoch 118/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1945 - accuracy: 0.9411 - val_loss: 0.1925 - val_accuracy: 0.9422 - lr: 3.9062e-07
# Epoch 119/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1943 - accuracy: 0.9410 - val_loss: 0.1925 - val_accuracy: 0.9422 - lr: 3.9062e-07
# Epoch 120/300
# 1204/1204 [==============================] - 9s 7ms/step - loss: 0.1943 - accuracy: 0.9411 - val_loss: 0.1926 - val_accuracy: 0.9418 - lr: 3.9062e-07
# Epoch 121/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1945 - accuracy: 0.9409 - val_loss: 0.1927 - val_accuracy: 0.9415 - lr: 3.9062e-07
# Epoch 122/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1940 - accuracy: 0.9409 - val_loss: 0.1927 - val_accuracy: 0.9421 - lr: 3.9062e-07
# Epoch 123/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1947 - accuracy: 0.9408 - val_loss: 0.1927 - val_accuracy: 0.9418 - lr: 3.9062e-07
# Epoch 124/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1940 - accuracy: 0.9409 - val_loss: 0.1925 - val_accuracy: 0.9419 - lr: 1.9531e-07
# Epoch 125/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1940 - accuracy: 0.9409 - val_loss: 0.1925 - val_accuracy: 0.9420 - lr: 1.9531e-07
# Epoch 126/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1942 - accuracy: 0.9415 - val_loss: 0.1926 - val_accuracy: 0.9414 - lr: 1.9531e-07
# Epoch 127/300
# 1204/1204 [==============================] - 10s 8ms/step - loss: 0.1942 - accuracy: 0.9411 - val_loss: 0.1926 - val_accuracy: 0.9419 - lr: 1.9531e-07
# Epoch 128/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1947 - accuracy: 0.9407 - val_loss: 0.1925 - val_accuracy: 0.9420 - lr: 1.9531e-07
# Epoch 129/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1942 - accuracy: 0.9411 - val_loss: 0.1926 - val_accuracy: 0.9419 - lr: 9.7656e-08
# Epoch 130/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1943 - accuracy: 0.9411 - val_loss: 0.1925 - val_accuracy: 0.9419 - lr: 9.7656e-08
# Epoch 131/300
# 1204/1204 [==============================] - 10s 8ms/step - loss: 0.1945 - accuracy: 0.9407 - val_loss: 0.1925 - val_accuracy: 0.9421 - lr: 9.7656e-08
# Epoch 132/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1940 - accuracy: 0.9411 - val_loss: 0.1925 - val_accuracy: 0.9420 - lr: 9.7656e-08
# Epoch 133/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1946 - accuracy: 0.9415 - val_loss: 0.1926 - val_accuracy: 0.9416 - lr: 9.7656e-08
# Epoch 134/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1940 - accuracy: 0.9412 - val_loss: 0.1925 - val_accuracy: 0.9420 - lr: 4.8828e-08
# Epoch 135/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1938 - accuracy: 0.9411 - val_loss: 0.1924 - val_accuracy: 0.9421 - lr: 4.8828e-08
# Epoch 136/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1936 - accuracy: 0.9411 - val_loss: 0.1924 - val_accuracy: 0.9421 - lr: 4.8828e-08
# Epoch 137/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1942 - accuracy: 0.9411 - val_loss: 0.1925 - val_accuracy: 0.9421 - lr: 4.8828e-08
# Epoch 138/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1941 - accuracy: 0.9408 - val_loss: 0.1925 - val_accuracy: 0.9420 - lr: 4.8828e-08
# Epoch 139/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1940 - accuracy: 0.9409 - val_loss: 0.1924 - val_accuracy: 0.9420 - lr: 2.4414e-08
# Epoch 140/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1938 - accuracy: 0.9411 - val_loss: 0.1925 - val_accuracy: 0.9419 - lr: 2.4414e-08
# Epoch 141/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1941 - accuracy: 0.9410 - val_loss: 0.1924 - val_accuracy: 0.9419 - lr: 2.4414e-08
# Epoch 142/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1942 - accuracy: 0.9413 - val_loss: 0.1925 - val_accuracy: 0.9421 - lr: 2.4414e-08
# Epoch 143/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1944 - accuracy: 0.9409 - val_loss: 0.1925 - val_accuracy: 0.9419 - lr: 2.4414e-08
# Epoch 144/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1935 - accuracy: 0.9412 - val_loss: 0.1924 - val_accuracy: 0.9421 - lr: 1.2207e-08
# Epoch 145/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1942 - accuracy: 0.9406 - val_loss: 0.1924 - val_accuracy: 0.9420 - lr: 1.2207e-08
# Epoch 146/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1940 - accuracy: 0.9407 - val_loss: 0.1924 - val_accuracy: 0.9421 - lr: 1.2207e-08
# Epoch 147/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1937 - accuracy: 0.9411 - val_loss: 0.1925 - val_accuracy: 0.9421 - lr: 1.2207e-08
# Epoch 148/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1941 - accuracy: 0.9412 - val_loss: 0.1925 - val_accuracy: 0.9420 - lr: 1.2207e-08
# Epoch 149/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1941 - accuracy: 0.9409 - val_loss: 0.1924 - val_accuracy: 0.9420 - lr: 6.1035e-09
# Epoch 150/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1944 - accuracy: 0.9409 - val_loss: 0.1924 - val_accuracy: 0.9423 - lr: 6.1035e-09
# Epoch 151/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1939 - accuracy: 0.9408 - val_loss: 0.1924 - val_accuracy: 0.9418 - lr: 6.1035e-09
# Epoch 152/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1938 - accuracy: 0.9410 - val_loss: 0.1925 - val_accuracy: 0.9420 - lr: 6.1035e-09
# Epoch 153/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1945 - accuracy: 0.9413 - val_loss: 0.1925 - val_accuracy: 0.9420 - lr: 6.1035e-09
# Epoch 154/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1940 - accuracy: 0.9412 - val_loss: 0.1924 - val_accuracy: 0.9421 - lr: 3.0518e-09
# Epoch 155/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1937 - accuracy: 0.9408 - val_loss: 0.1924 - val_accuracy: 0.9419 - lr: 3.0518e-09
# Epoch 156/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1941 - accuracy: 0.9410 - val_loss: 0.1924 - val_accuracy: 0.9421 - lr: 3.0518e-09
# Epoch 157/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1941 - accuracy: 0.9411 - val_loss: 0.1924 - val_accuracy: 0.9420 - lr: 3.0518e-09
# Epoch 158/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1946 - accuracy: 0.9408 - val_loss: 0.1925 - val_accuracy: 0.9417 - lr: 3.0518e-09
# Epoch 159/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1941 - accuracy: 0.9409 - val_loss: 0.1925 - val_accuracy: 0.9420 - lr: 1.5259e-09
# Epoch 160/300
# 1204/1204 [==============================] - 10s 8ms/step - loss: 0.1940 - accuracy: 0.9408 - val_loss: 0.1924 - val_accuracy: 0.9420 - lr: 1.5259e-09
# Epoch 161/300
# 1204/1204 [==============================] - 9s 8ms/step - loss: 0.1940 - accuracy: 0.9410 - val_loss: 0.1924 - val_accuracy: 0.9421 - lr: 1.5259e-09
# Epoch 162/300
# 1204/1204 [==============================] - 10s 8ms/step - loss: 0.1944 - accuracy: 0.9408 - val_loss: 0.1925 - val_accuracy: 0.9418 - lr: 1.5259e-09
# Epoch 163/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1941 - accuracy: 0.9412 - val_loss: 0.1924 - val_accuracy: 0.9419 - lr: 1.5259e-09
# Epoch 164/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.1941 - accuracy: 0.9412 - val_loss: 0.1925 - val_accuracy: 0.9420 - lr: 7.6294e-10
# Epoch 165/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.1937 - accuracy: 0.9415 - val_loss: 0.1925 - val_accuracy: 0.9418 - lr: 7.6294e-10
# Epoch 166/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.1938 - accuracy: 0.9413 - val_loss: 0.1925 - val_accuracy: 0.9419 - lr: 7.6294e-10
# Epoch 167/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.1939 - accuracy: 0.9411 - val_loss: 0.1924 - val_accuracy: 0.9419 - lr: 7.6294e-10
# Epoch 168/300
# 1204/1204 [==============================] - 8s 7ms/step - loss: 0.1943 - accuracy: 0.9409 - val_loss: 0.1925 - val_accuracy: 0.9418 - lr: 7.6294e-10
# Epoch 169/300
# 1204/1204 [==============================] - 7s 6ms/step - loss: 0.1944 - accuracy: 0.9409 - val_loss: 0.1924 - val_accuracy: 0.9421 - lr: 3.8147e-10
# Epoch 170/300
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.1941 - accuracy: 0.9416 - val_loss: 0.1924 - val_accuracy: 0.9419 - lr: 3.8147e-10
# Epoch 171/300
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.1938 - accuracy: 0.9410 - val_loss: 0.1925 - val_accuracy: 0.9419 - lr: 3.8147e-10
# Epoch 172/300
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.1941 - accuracy: 0.9414 - val_loss: 0.1924 - val_accuracy: 0.9419 - lr: 3.8147e-10
# Epoch 173/300
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.1945 - accuracy: 0.9408 - val_loss: 0.1924 - val_accuracy: 0.9420 - lr: 3.8147e-10
# Epoch 174/300
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.1938 - accuracy: 0.9412 - val_loss: 0.1924 - val_accuracy: 0.9419 - lr: 1.9073e-10
# Epoch 175/300
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.1941 - accuracy: 0.9411 - val_loss: 0.1924 - val_accuracy: 0.9419 - lr: 1.9073e-10
# Epoch 176/300
# 1204/1204 [==============================] - 8s 6ms/step - loss: 0.1938 - accuracy: 0.9414 - val_loss: 0.1925 - val_accuracy: 0.9419 - lr: 1.9073e-10
# ✅ Huấn luyện xong. Hiển thị biểu đồ...
# 🔎 Dự đoán trên tập test...
# 1376/1376 [==============================] - 2s 2ms/step
# 📊 Ma trận nhầm lẫn:
# 📋 Classification Report:
#                 precision    recall  f1-score   support
#
#         benign     0.9877    0.9637    0.9756      4000
#     bruteforce     0.9955    0.9958    0.9956      4000
#            dos     0.9355    0.8772    0.9054      4000
#            ftp     0.9941    0.9233    0.9574      4000
# reconnaissance     1.0000    1.0000    1.0000      4000
#  reverse_shell     0.9378    0.8482    0.8908      4000
#           smtp     0.9290    0.9973    0.9619      4001
#  sql_injection     0.8883    0.9287    0.9081      4000
#            ssh     0.9993    0.9995    0.9994      4000
#           ssrf     0.8904    0.8592    0.8746      4000
#            xss     0.8229    0.9617    0.8869      4000
#
#       accuracy                         0.9413     44001
#      macro avg     0.9437    0.9413    0.9414     44001
#   weighted avg     0.9437    0.9413    0.9414     44001
#
#
# 📈 Precision-Recall từng lớp:
# ✅ Test Accuracy: 0.9413 - Test Loss: 0.1935
#
# ✅ Test Accuracy: 0.9413 - Test Loss: 0.1935
# 💾 Mô hình đã được lưu vào: cnn_webids23_model.h5

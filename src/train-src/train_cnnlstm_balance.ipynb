# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, BatchNormalization, GlobalAveragePooling1D
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Dropout, GaussianNoise
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import precision_recall_curve, average_precision_score
from tensorflow.keras.losses import CategoricalCrossentropy
# ==== 1. Tên lớp gộp ====
class_names = [
    'benign', 'bruteforce', 'dos', 'ftp', 'reconnaissance',
    'reverse_shell', 'smtp', 'sql_injection', 'ssh', 'ssrf', 'xss'
]

# ==== 2. Hàm reshape an toàn ====
def safe_reshape(X, n_features=35):
    if len(X.shape) == 1:
        assert X.size % n_features == 0, "Tổng phần tử không chia hết cho số đặc trưng"
        X = X.reshape(-1, n_features)
    elif X.shape[1] != n_features:
        raise ValueError(f"Số đặc trưng không đúng. Mong đợi {n_features}, nhưng nhận được {X.shape[1]}")
    return X.reshape(-1, n_features, 1)

# ==== 3. Load và xử lý dữ liệu ====
def load_data(data_path):
    X_train = np.load(os.path.join(data_path, 'X_train.npy'))
    y_train = np.load(os.path.join(data_path, 'y_train.npy'))
    X_val   = np.load(os.path.join(data_path, 'X_val.npy'))
    y_val   = np.load(os.path.join(data_path, 'y_val.npy'))
    X_test  = np.load(os.path.join(data_path, 'X_test.npy'))
    y_test  = np.load(os.path.join(data_path, 'y_test.npy'))

    X_train = safe_reshape(X_train, n_features=35)
    X_val   = safe_reshape(X_val, n_features=35)
    X_test  = safe_reshape(X_test, n_features=35)
    print("Phân bố lớp:", np.sum(y_train, axis=0))
    return X_train, y_train, X_val, y_val, X_test, y_test

def build_cnn_lstm_model(input_shape=(35, 1), num_classes=11):
    model = Sequential()

    # CNN block 1
    model.add(Conv1D(64, kernel_size=3, activation='relu', padding='same',
                     kernel_regularizer=l2(0.0005), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2, strides=2))

    # CNN block 2
    model.add(Conv1D(128, kernel_size=3, activation='relu', padding='same',
                     kernel_regularizer=l2(0.0005)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2, strides=2))

    # LSTM block
    model.add(LSTM(128, return_sequences=True,
                   dropout=0.2, recurrent_dropout=0.2,
                   kernel_regularizer=l2(0.0005)))
    model.add(BatchNormalization())

    # Dense block
    model.add(Dense(128, activation='relu', kernel_regularizer=l2(0.0005)))
    model.add(Dropout(0.3))

    # Output layer
    model.add(Dense(num_classes, activation='softmax'))

    # Optimizer
    optimizer = Adam(learning_rate=5e-4, clipnorm=1.0)

    model.compile(optimizer=optimizer,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    return model
# ==== 5. Biểu đồ training ====
def plot_history(history):
    plt.figure(figsize=(14, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Loss over Epochs')
    plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Acc')
    plt.plot(history.history['val_accuracy'], label='Val Acc')
    plt.title('Accuracy over Epochs')
    plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend()

    plt.tight_layout()
    plt.show()

# ==== 6. Ma trận nhầm lẫn ====
def plot_confusion_matrix(y_true, y_pred, class_names):
    cm = confusion_matrix(y_true, y_pred)
    cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    cm_percent = np.round(cm_percent * 100, 2)

    plt.figure(figsize=(10, 8))
    sns.heatmap(cm_percent, annot=True, fmt='.2f', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Dự đoán')
    plt.ylabel('Thực tế')
    plt.title('Ma Trận Nhầm lẫn')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# ==== 7. Precision-Recall ==== 
def plot_precision_recall(y_true_onehot, y_pred_probs, class_names):
    precision, recall, ap_score = dict(), dict(), dict()
    n_classes = y_true_onehot.shape[1]

    plt.figure(figsize=(10, 8))
    for i in range(n_classes):
        precision[i], recall[i], _ = precision_recall_curve(y_true_onehot[:, i], y_pred_probs[:, i])
        ap_score[i] = average_precision_score(y_true_onehot[:, i], y_pred_probs[:, i])
        plt.plot(recall[i], precision[i], 
                 label=f"{class_names[i]} (AP = {ap_score[i]:.2f})")

    # Micro-average (tổng hợp toàn bộ)
    precision_micro, recall_micro, _ = precision_recall_curve(y_true_onehot.ravel(), y_pred_probs.ravel())
    ap_micro = average_precision_score(y_true_onehot, y_pred_probs, average="micro")
    plt.plot(recall_micro, precision_micro,
             label=f"Micro-average (AP = {ap_micro:.2f})", color='black', linestyle='--')

    plt.title("Precision-Recall Curves for All Classes")
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.legend(loc="lower left")
    plt.grid()
    plt.show()

# ==== 8. Main pipeline ====
def main():
    data_path = r'D:/webids23_processed1/'
    print("🔄 Đang load dữ liệu...")
    X_train, y_train, X_val, y_val, X_test, y_test = load_data(data_path)

    print("✅ Dữ liệu đã được load. Bắt đầu xây dựng mô hình CNN-LSTM...")
    model = build_cnn_lstm_model()

    callbacks = [
        EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)
    ]
    model.summary()
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=300,  # Giảm epoch để tránh overfit
        batch_size=128,  # Giảm batch_size để tăng tính ổn định
        callbacks=callbacks,
        verbose=1
    )

    print("✅ Huấn luyện xong. Hiển thị biểu đồ...")
    plot_history(history)

    print("🔎 Dự đoán trên tập test...")
    y_pred_probs = model.predict(X_test)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test, axis=1)

    print("📊 Ma trận nhầm lẫn:")
    plot_confusion_matrix(y_true, y_pred, class_names)

    print("\n📋 Classification Report:")
    print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

    print("\n📈 Precision-Recall từng lớp:")
    plot_precision_recall(y_test, y_pred_probs, class_names)

    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
    print(f"\n✅ Test Accuracy: {test_acc:.4f} - Test Loss: {test_loss:.4f}")

    model.save("cnn_lstm_webids23_model.h5")
    print("💾 Mô hình đã được lưu vào: cnn_lstm_webids23_model.h5")

# ==== 9. Chạy chương trình ====
if __name__ == "__main__":
    main()
# Out:
# 🔄 Đang load dữ liệu...
# Phân bố lớp: [14000. 14000. 14000. 14000. 14000. 14000. 13999. 14000. 14000. 14000.
#  14000.]
# ✅ Dữ liệu đã được load. Bắt đầu xây dựng mô hình CNN-LSTM...
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 35, 64)            256
#
#  batch_normalization (BatchN  (None, 35, 64)           256
#  ormalization)
#
#  max_pooling1d (MaxPooling1D  (None, 18, 64)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 18, 128)           24704
#
#  batch_normalization_1 (Batc  (None, 18, 128)          512
#  hNormalization)
#
#  max_pooling1d_1 (MaxPooling  (None, 9, 128)           0
#  1D)
#
#  lstm (LSTM)                 (None, 128)               131584
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 11)                1419
#
# =================================================================
# Total params: 175,243
# Trainable params: 174,859
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/300
# 1204/1204 [==============================] - 19s 11ms/step - loss: 1.2105 - accuracy: 0.6145 - val_loss: 0.9695 - val_accuracy: 0.6593 - lr: 5.0000e-04
# Epoch 2/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.7145 - accuracy: 0.7871 - val_loss: 2.9171 - val_accuracy: 0.4129 - lr: 5.0000e-04
# Epoch 3/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.5003 - accuracy: 0.8599 - val_loss: 1.5266 - val_accuracy: 0.6245 - lr: 5.0000e-04
# Epoch 4/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.4085 - accuracy: 0.8842 - val_loss: 1.1678 - val_accuracy: 0.6614 - lr: 5.0000e-04
# Epoch 5/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.3605 - accuracy: 0.8954 - val_loss: 1.4294 - val_accuracy: 0.6817 - lr: 5.0000e-04
# Epoch 6/300
# 1204/1204 [==============================] - 13s 10ms/step - loss: 0.3313 - accuracy: 0.9011 - val_loss: 1.9777 - val_accuracy: 0.5432 - lr: 5.0000e-04
# Epoch 7/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.2931 - accuracy: 0.9109 - val_loss: 0.3235 - val_accuracy: 0.8975 - lr: 2.5000e-04
# Epoch 8/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.2838 - accuracy: 0.9125 - val_loss: 1.9478 - val_accuracy: 0.5549 - lr: 2.5000e-04
# Epoch 9/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.2777 - accuracy: 0.9125 - val_loss: 0.5028 - val_accuracy: 0.8265 - lr: 2.5000e-04
# Epoch 10/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.2699 - accuracy: 0.9141 - val_loss: 2.2274 - val_accuracy: 0.5995 - lr: 2.5000e-04
# Epoch 11/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.2632 - accuracy: 0.9152 - val_loss: 1.1535 - val_accuracy: 0.6291 - lr: 2.5000e-04
# Epoch 12/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.2558 - accuracy: 0.9175 - val_loss: 2.0130 - val_accuracy: 0.6260 - lr: 2.5000e-04
# Epoch 13/300
# 1204/1204 [==============================] - 13s 10ms/step - loss: 0.2352 - accuracy: 0.9259 - val_loss: 0.6620 - val_accuracy: 0.8559 - lr: 1.2500e-04
# Epoch 14/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.2277 - accuracy: 0.9276 - val_loss: 0.3008 - val_accuracy: 0.9055 - lr: 1.2500e-04
# Epoch 15/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.2296 - accuracy: 0.9261 - val_loss: 0.3311 - val_accuracy: 0.8583 - lr: 1.2500e-04
# Epoch 16/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.2273 - accuracy: 0.9270 - val_loss: 0.2678 - val_accuracy: 0.9165 - lr: 1.2500e-04
# Epoch 17/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.2260 - accuracy: 0.9265 - val_loss: 0.2916 - val_accuracy: 0.9153 - lr: 1.2500e-04
# Epoch 18/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.2265 - accuracy: 0.9271 - val_loss: 0.4981 - val_accuracy: 0.8556 - lr: 1.2500e-04
# Epoch 19/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.2261 - accuracy: 0.9272 - val_loss: 1.2864 - val_accuracy: 0.7240 - lr: 1.2500e-04
# Epoch 20/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.2209 - accuracy: 0.9289 - val_loss: 0.2353 - val_accuracy: 0.9249 - lr: 1.2500e-04
# Epoch 21/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.2227 - accuracy: 0.9284 - val_loss: 0.3555 - val_accuracy: 0.8791 - lr: 1.2500e-04
# Epoch 22/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.2227 - accuracy: 0.9280 - val_loss: 0.2553 - val_accuracy: 0.9251 - lr: 1.2500e-04
# Epoch 23/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.2200 - accuracy: 0.9289 - val_loss: 0.8938 - val_accuracy: 0.7468 - lr: 1.2500e-04
# Epoch 24/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.2199 - accuracy: 0.9291 - val_loss: 0.3464 - val_accuracy: 0.8545 - lr: 1.2500e-04
# Epoch 25/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.2156 - accuracy: 0.9308 - val_loss: 0.7775 - val_accuracy: 0.8297 - lr: 1.2500e-04
# Epoch 26/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.2072 - accuracy: 0.9328 - val_loss: 0.4715 - val_accuracy: 0.8620 - lr: 6.2500e-05
# Epoch 27/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.2046 - accuracy: 0.9336 - val_loss: 0.2952 - val_accuracy: 0.8827 - lr: 6.2500e-05
# Epoch 28/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.2056 - accuracy: 0.9332 - val_loss: 0.3904 - val_accuracy: 0.8435 - lr: 6.2500e-05
# Epoch 29/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.2033 - accuracy: 0.9332 - val_loss: 0.2066 - val_accuracy: 0.9331 - lr: 6.2500e-05
# Epoch 30/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.2014 - accuracy: 0.9341 - val_loss: 0.4360 - val_accuracy: 0.8562 - lr: 6.2500e-05
# Epoch 31/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.2009 - accuracy: 0.9347 - val_loss: 0.3449 - val_accuracy: 0.9144 - lr: 6.2500e-05
# Epoch 32/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.2004 - accuracy: 0.9343 - val_loss: 0.2080 - val_accuracy: 0.9326 - lr: 6.2500e-05
# Epoch 33/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.2009 - accuracy: 0.9340 - val_loss: 0.2346 - val_accuracy: 0.9250 - lr: 6.2500e-05
# Epoch 34/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.2004 - accuracy: 0.9339 - val_loss: 0.2016 - val_accuracy: 0.9325 - lr: 6.2500e-05
# Epoch 35/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.2006 - accuracy: 0.9340 - val_loss: 0.9408 - val_accuracy: 0.7039 - lr: 6.2500e-05
# Epoch 36/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1993 - accuracy: 0.9341 - val_loss: 0.2110 - val_accuracy: 0.9323 - lr: 6.2500e-05
# Epoch 37/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1992 - accuracy: 0.9341 - val_loss: 0.2020 - val_accuracy: 0.9331 - lr: 6.2500e-05
# Epoch 38/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1986 - accuracy: 0.9343 - val_loss: 0.2474 - val_accuracy: 0.9241 - lr: 6.2500e-05
# Epoch 39/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1968 - accuracy: 0.9345 - val_loss: 0.2285 - val_accuracy: 0.9264 - lr: 6.2500e-05
# Epoch 40/300
# 1204/1204 [==============================] - 13s 10ms/step - loss: 0.1925 - accuracy: 0.9363 - val_loss: 0.1940 - val_accuracy: 0.9352 - lr: 3.1250e-05
# Epoch 41/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1934 - accuracy: 0.9363 - val_loss: 0.2218 - val_accuracy: 0.9282 - lr: 3.1250e-05
# Epoch 42/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1922 - accuracy: 0.9363 - val_loss: 0.2069 - val_accuracy: 0.9326 - lr: 3.1250e-05
# Epoch 43/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1921 - accuracy: 0.9366 - val_loss: 0.1942 - val_accuracy: 0.9358 - lr: 3.1250e-05
# Epoch 44/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1921 - accuracy: 0.9366 - val_loss: 0.1951 - val_accuracy: 0.9361 - lr: 3.1250e-05
# Epoch 45/300
# 1204/1204 [==============================] - 13s 10ms/step - loss: 0.1918 - accuracy: 0.9366 - val_loss: 0.2226 - val_accuracy: 0.9278 - lr: 3.1250e-05
# Epoch 46/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1893 - accuracy: 0.9375 - val_loss: 0.1939 - val_accuracy: 0.9359 - lr: 1.5625e-05
# Epoch 47/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1888 - accuracy: 0.9377 - val_loss: 0.1924 - val_accuracy: 0.9354 - lr: 1.5625e-05
# Epoch 48/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1885 - accuracy: 0.9375 - val_loss: 0.1890 - val_accuracy: 0.9374 - lr: 1.5625e-05
# Epoch 49/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1889 - accuracy: 0.9378 - val_loss: 0.2007 - val_accuracy: 0.9345 - lr: 1.5625e-05
# Epoch 50/300
# 1204/1204 [==============================] - 13s 10ms/step - loss: 0.1887 - accuracy: 0.9375 - val_loss: 0.1894 - val_accuracy: 0.9373 - lr: 1.5625e-05
# Epoch 51/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1888 - accuracy: 0.9372 - val_loss: 0.1895 - val_accuracy: 0.9382 - lr: 1.5625e-05
# Epoch 52/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1884 - accuracy: 0.9372 - val_loss: 0.1939 - val_accuracy: 0.9355 - lr: 1.5625e-05
# Epoch 53/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1890 - accuracy: 0.9374 - val_loss: 0.1907 - val_accuracy: 0.9357 - lr: 1.5625e-05
# Epoch 54/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1871 - accuracy: 0.9378 - val_loss: 0.1873 - val_accuracy: 0.9377 - lr: 7.8125e-06
# Epoch 55/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1872 - accuracy: 0.9379 - val_loss: 0.1876 - val_accuracy: 0.9398 - lr: 7.8125e-06
# Epoch 56/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1867 - accuracy: 0.9380 - val_loss: 0.1872 - val_accuracy: 0.9379 - lr: 7.8125e-06
# Epoch 57/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1867 - accuracy: 0.9378 - val_loss: 0.1881 - val_accuracy: 0.9385 - lr: 7.8125e-06
# Epoch 58/300
# 1204/1204 [==============================] - 13s 10ms/step - loss: 0.1862 - accuracy: 0.9383 - val_loss: 0.1880 - val_accuracy: 0.9372 - lr: 7.8125e-06
# Epoch 59/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1868 - accuracy: 0.9381 - val_loss: 0.1923 - val_accuracy: 0.9370 - lr: 7.8125e-06
# Epoch 60/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1856 - accuracy: 0.9386 - val_loss: 0.1869 - val_accuracy: 0.9399 - lr: 3.9063e-06
# Epoch 61/300
# 1204/1204 [==============================] - 13s 10ms/step - loss: 0.1859 - accuracy: 0.9380 - val_loss: 0.1879 - val_accuracy: 0.9378 - lr: 3.9063e-06
# Epoch 62/300
# 1204/1204 [==============================] - 13s 10ms/step - loss: 0.1856 - accuracy: 0.9385 - val_loss: 0.1864 - val_accuracy: 0.9385 - lr: 3.9063e-06
# Epoch 63/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1856 - accuracy: 0.9387 - val_loss: 0.1868 - val_accuracy: 0.9375 - lr: 3.9063e-06
# Epoch 64/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1855 - accuracy: 0.9383 - val_loss: 0.1874 - val_accuracy: 0.9372 - lr: 3.9063e-06
# Epoch 65/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1852 - accuracy: 0.9389 - val_loss: 0.1866 - val_accuracy: 0.9382 - lr: 3.9063e-06
# Epoch 66/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1852 - accuracy: 0.9389 - val_loss: 0.1862 - val_accuracy: 0.9392 - lr: 3.9063e-06
# Epoch 67/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1854 - accuracy: 0.9385 - val_loss: 0.1864 - val_accuracy: 0.9388 - lr: 3.9063e-06
# Epoch 68/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1847 - accuracy: 0.9389 - val_loss: 0.1867 - val_accuracy: 0.9399 - lr: 3.9063e-06
# Epoch 69/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1854 - accuracy: 0.9387 - val_loss: 0.1862 - val_accuracy: 0.9388 - lr: 3.9063e-06
# Epoch 70/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1857 - accuracy: 0.9385 - val_loss: 0.1859 - val_accuracy: 0.9385 - lr: 3.9063e-06
# Epoch 71/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1850 - accuracy: 0.9386 - val_loss: 0.1870 - val_accuracy: 0.9394 - lr: 3.9063e-06
# Epoch 72/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1850 - accuracy: 0.9388 - val_loss: 0.1870 - val_accuracy: 0.9362 - lr: 3.9063e-06
# Epoch 73/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1855 - accuracy: 0.9385 - val_loss: 0.1889 - val_accuracy: 0.9378 - lr: 3.9063e-06
# Epoch 74/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1854 - accuracy: 0.9383 - val_loss: 0.1864 - val_accuracy: 0.9373 - lr: 3.9063e-06
# Epoch 75/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1853 - accuracy: 0.9383 - val_loss: 0.1867 - val_accuracy: 0.9387 - lr: 3.9063e-06
# Epoch 76/300
# 1204/1204 [==============================] - 13s 10ms/step - loss: 0.1853 - accuracy: 0.9386 - val_loss: 0.1870 - val_accuracy: 0.9373 - lr: 1.9531e-06
# Epoch 77/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1844 - accuracy: 0.9387 - val_loss: 0.1858 - val_accuracy: 0.9407 - lr: 1.9531e-06
# Epoch 78/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1851 - accuracy: 0.9389 - val_loss: 0.1856 - val_accuracy: 0.9388 - lr: 1.9531e-06
# Epoch 79/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1847 - accuracy: 0.9387 - val_loss: 0.1860 - val_accuracy: 0.9382 - lr: 1.9531e-06
# Epoch 80/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1849 - accuracy: 0.9389 - val_loss: 0.1858 - val_accuracy: 0.9380 - lr: 1.9531e-06
# Epoch 81/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1847 - accuracy: 0.9389 - val_loss: 0.1858 - val_accuracy: 0.9403 - lr: 1.9531e-06
# Epoch 82/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1848 - accuracy: 0.9390 - val_loss: 0.1857 - val_accuracy: 0.9386 - lr: 1.9531e-06
# Epoch 83/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1845 - accuracy: 0.9389 - val_loss: 0.1858 - val_accuracy: 0.9380 - lr: 1.9531e-06
# Epoch 84/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1845 - accuracy: 0.9390 - val_loss: 0.1858 - val_accuracy: 0.9382 - lr: 9.7656e-07
# Epoch 85/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1852 - accuracy: 0.9389 - val_loss: 0.1857 - val_accuracy: 0.9385 - lr: 9.7656e-07
# Epoch 86/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1846 - accuracy: 0.9387 - val_loss: 0.1854 - val_accuracy: 0.9390 - lr: 9.7656e-07
# Epoch 87/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1842 - accuracy: 0.9390 - val_loss: 0.1855 - val_accuracy: 0.9397 - lr: 9.7656e-07
# Epoch 88/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1842 - accuracy: 0.9393 - val_loss: 0.1858 - val_accuracy: 0.9385 - lr: 9.7656e-07
# Epoch 89/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1844 - accuracy: 0.9391 - val_loss: 0.1856 - val_accuracy: 0.9383 - lr: 9.7656e-07
# Epoch 90/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1846 - accuracy: 0.9391 - val_loss: 0.1853 - val_accuracy: 0.9382 - lr: 9.7656e-07
# Epoch 91/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1841 - accuracy: 0.9391 - val_loss: 0.1854 - val_accuracy: 0.9385 - lr: 9.7656e-07
# Epoch 92/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1838 - accuracy: 0.9393 - val_loss: 0.1853 - val_accuracy: 0.9390 - lr: 4.8828e-07
# Epoch 93/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1842 - accuracy: 0.9393 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 4.8828e-07
# Epoch 94/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1841 - accuracy: 0.9387 - val_loss: 0.1853 - val_accuracy: 0.9399 - lr: 4.8828e-07
# Epoch 95/300
# 1204/1204 [==============================] - 13s 10ms/step - loss: 0.1842 - accuracy: 0.9391 - val_loss: 0.1852 - val_accuracy: 0.9394 - lr: 4.8828e-07
# Epoch 96/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1839 - accuracy: 0.9391 - val_loss: 0.1852 - val_accuracy: 0.9390 - lr: 4.8828e-07
# Epoch 97/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1841 - accuracy: 0.9389 - val_loss: 0.1853 - val_accuracy: 0.9388 - lr: 4.8828e-07
# Epoch 98/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1841 - accuracy: 0.9388 - val_loss: 0.1853 - val_accuracy: 0.9388 - lr: 4.8828e-07
# Epoch 99/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1843 - accuracy: 0.9391 - val_loss: 0.1853 - val_accuracy: 0.9390 - lr: 2.4414e-07
# Epoch 100/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1841 - accuracy: 0.9389 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 2.4414e-07
# Epoch 101/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1840 - accuracy: 0.9393 - val_loss: 0.1853 - val_accuracy: 0.9384 - lr: 2.4414e-07
# Epoch 102/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1843 - accuracy: 0.9390 - val_loss: 0.1853 - val_accuracy: 0.9388 - lr: 2.4414e-07
# Epoch 103/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1841 - accuracy: 0.9391 - val_loss: 0.1852 - val_accuracy: 0.9399 - lr: 2.4414e-07
# Epoch 104/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1842 - accuracy: 0.9391 - val_loss: 0.1852 - val_accuracy: 0.9390 - lr: 1.2207e-07
# Epoch 105/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1839 - accuracy: 0.9398 - val_loss: 0.1852 - val_accuracy: 0.9386 - lr: 1.2207e-07
# Epoch 106/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1838 - accuracy: 0.9392 - val_loss: 0.1852 - val_accuracy: 0.9384 - lr: 1.2207e-07
# Epoch 107/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1844 - accuracy: 0.9391 - val_loss: 0.1853 - val_accuracy: 0.9384 - lr: 1.2207e-07
# Epoch 108/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1843 - accuracy: 0.9388 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 1.2207e-07
# Epoch 109/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1846 - accuracy: 0.9389 - val_loss: 0.1852 - val_accuracy: 0.9386 - lr: 6.1035e-08
# Epoch 110/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1841 - accuracy: 0.9387 - val_loss: 0.1852 - val_accuracy: 0.9389 - lr: 6.1035e-08
# Epoch 111/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1844 - accuracy: 0.9391 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 6.1035e-08
# Epoch 112/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1839 - accuracy: 0.9393 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 6.1035e-08
# Epoch 113/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1833 - accuracy: 0.9394 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 6.1035e-08
# Epoch 114/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1838 - accuracy: 0.9394 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 3.0518e-08
# Epoch 115/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1844 - accuracy: 0.9389 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 3.0518e-08
# Epoch 116/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1842 - accuracy: 0.9392 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 3.0518e-08
# Epoch 117/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1844 - accuracy: 0.9388 - val_loss: 0.1853 - val_accuracy: 0.9385 - lr: 3.0518e-08
# Epoch 118/300
# 1204/1204 [==============================] - 13s 10ms/step - loss: 0.1837 - accuracy: 0.9391 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 3.0518e-08
# Epoch 119/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1845 - accuracy: 0.9388 - val_loss: 0.1852 - val_accuracy: 0.9388 - lr: 1.5259e-08
# Epoch 120/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1840 - accuracy: 0.9393 - val_loss: 0.1852 - val_accuracy: 0.9388 - lr: 1.5259e-08
# Epoch 121/300
# 1204/1204 [==============================] - 14s 11ms/step - loss: 0.1841 - accuracy: 0.9389 - val_loss: 0.1853 - val_accuracy: 0.9386 - lr: 1.5259e-08
# Epoch 122/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1843 - accuracy: 0.9387 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 1.5259e-08
# Epoch 123/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1840 - accuracy: 0.9391 - val_loss: 0.1852 - val_accuracy: 0.9386 - lr: 1.5259e-08
# Epoch 124/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1842 - accuracy: 0.9394 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 7.6294e-09
# Epoch 125/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1843 - accuracy: 0.9392 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 7.6294e-09
# Epoch 126/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1840 - accuracy: 0.9394 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 7.6294e-09
# Epoch 127/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1840 - accuracy: 0.9390 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 7.6294e-09
# Epoch 128/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1839 - accuracy: 0.9391 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 7.6294e-09
# Epoch 129/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1844 - accuracy: 0.9390 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 3.8147e-09
# Epoch 130/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1838 - accuracy: 0.9390 - val_loss: 0.1852 - val_accuracy: 0.9388 - lr: 3.8147e-09
# Epoch 131/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1841 - accuracy: 0.9390 - val_loss: 0.1852 - val_accuracy: 0.9386 - lr: 3.8147e-09
# Epoch 132/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1841 - accuracy: 0.9387 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 3.8147e-09
# Epoch 133/300
# 1204/1204 [==============================] - 13s 10ms/step - loss: 0.1836 - accuracy: 0.9393 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 3.8147e-09
# Epoch 134/300
# 1204/1204 [==============================] - 13s 10ms/step - loss: 0.1840 - accuracy: 0.9389 - val_loss: 0.1851 - val_accuracy: 0.9388 - lr: 1.9073e-09
# Epoch 135/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1841 - accuracy: 0.9388 - val_loss: 0.1851 - val_accuracy: 0.9385 - lr: 1.9073e-09
# Epoch 136/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1843 - accuracy: 0.9388 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 1.9073e-09
# Epoch 137/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1840 - accuracy: 0.9390 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 1.9073e-09
# Epoch 138/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1840 - accuracy: 0.9391 - val_loss: 0.1852 - val_accuracy: 0.9386 - lr: 1.9073e-09
# Epoch 139/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1843 - accuracy: 0.9388 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 9.5367e-10
# Epoch 140/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1840 - accuracy: 0.9389 - val_loss: 0.1852 - val_accuracy: 0.9388 - lr: 9.5367e-10
# Epoch 141/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1837 - accuracy: 0.9392 - val_loss: 0.1852 - val_accuracy: 0.9384 - lr: 9.5367e-10
# Epoch 142/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1838 - accuracy: 0.9394 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 9.5367e-10
# Epoch 143/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1839 - accuracy: 0.9391 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 9.5367e-10
# Epoch 144/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1842 - accuracy: 0.9395 - val_loss: 0.1852 - val_accuracy: 0.9384 - lr: 4.7684e-10
# Epoch 145/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1842 - accuracy: 0.9392 - val_loss: 0.1852 - val_accuracy: 0.9391 - lr: 4.7684e-10
# Epoch 146/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1840 - accuracy: 0.9389 - val_loss: 0.1852 - val_accuracy: 0.9390 - lr: 4.7684e-10
# Epoch 147/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1838 - accuracy: 0.9396 - val_loss: 0.1852 - val_accuracy: 0.9388 - lr: 4.7684e-10
# Epoch 148/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1839 - accuracy: 0.9390 - val_loss: 0.1852 - val_accuracy: 0.9386 - lr: 4.7684e-10
# Epoch 149/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1843 - accuracy: 0.9389 - val_loss: 0.1852 - val_accuracy: 0.9388 - lr: 2.3842e-10
# Epoch 150/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1841 - accuracy: 0.9390 - val_loss: 0.1852 - val_accuracy: 0.9388 - lr: 2.3842e-10
# Epoch 151/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1844 - accuracy: 0.9388 - val_loss: 0.1852 - val_accuracy: 0.9389 - lr: 2.3842e-10
# Epoch 152/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1841 - accuracy: 0.9392 - val_loss: 0.1851 - val_accuracy: 0.9387 - lr: 2.3842e-10
# Epoch 153/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1841 - accuracy: 0.9390 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 2.3842e-10
# Epoch 154/300
# 1204/1204 [==============================] - 13s 10ms/step - loss: 0.1846 - accuracy: 0.9395 - val_loss: 0.1852 - val_accuracy: 0.9384 - lr: 2.3842e-10
# Epoch 155/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1839 - accuracy: 0.9394 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 2.3842e-10
# Epoch 156/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1838 - accuracy: 0.9389 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 2.3842e-10
# Epoch 157/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1847 - accuracy: 0.9387 - val_loss: 0.1851 - val_accuracy: 0.9387 - lr: 2.3842e-10
# Epoch 158/300
# 1204/1204 [==============================] - 13s 10ms/step - loss: 0.1837 - accuracy: 0.9394 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 1.1921e-10
# Epoch 159/300
# 1204/1204 [==============================] - 13s 10ms/step - loss: 0.1842 - accuracy: 0.9391 - val_loss: 0.1852 - val_accuracy: 0.9386 - lr: 1.1921e-10
# Epoch 160/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1838 - accuracy: 0.9393 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 1.1921e-10
# Epoch 161/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1840 - accuracy: 0.9389 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 1.1921e-10
# Epoch 162/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1841 - accuracy: 0.9392 - val_loss: 0.1851 - val_accuracy: 0.9388 - lr: 1.1921e-10
# Epoch 163/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1840 - accuracy: 0.9394 - val_loss: 0.1851 - val_accuracy: 0.9384 - lr: 5.9605e-11
# Epoch 164/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1838 - accuracy: 0.9392 - val_loss: 0.1853 - val_accuracy: 0.9385 - lr: 5.9605e-11
# Epoch 165/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1841 - accuracy: 0.9387 - val_loss: 0.1852 - val_accuracy: 0.9388 - lr: 5.9605e-11
# Epoch 166/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1842 - accuracy: 0.9388 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 5.9605e-11
# Epoch 167/300
# 1204/1204 [==============================] - 14s 11ms/step - loss: 0.1838 - accuracy: 0.9392 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 5.9605e-11
# Epoch 168/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1842 - accuracy: 0.9392 - val_loss: 0.1852 - val_accuracy: 0.9386 - lr: 2.9802e-11
# Epoch 169/300
# 1204/1204 [==============================] - 13s 10ms/step - loss: 0.1847 - accuracy: 0.9387 - val_loss: 0.1852 - val_accuracy: 0.9391 - lr: 2.9802e-11
# Epoch 170/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1841 - accuracy: 0.9391 - val_loss: 0.1851 - val_accuracy: 0.9390 - lr: 2.9802e-11
# Epoch 171/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1843 - accuracy: 0.9389 - val_loss: 0.1852 - val_accuracy: 0.9386 - lr: 2.9802e-11
# Epoch 172/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1837 - accuracy: 0.9395 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 2.9802e-11
# Epoch 173/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1841 - accuracy: 0.9392 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 1.4901e-11
# Epoch 174/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1839 - accuracy: 0.9390 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 1.4901e-11
# Epoch 175/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1841 - accuracy: 0.9390 - val_loss: 0.1853 - val_accuracy: 0.9386 - lr: 1.4901e-11
# Epoch 176/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1842 - accuracy: 0.9391 - val_loss: 0.1853 - val_accuracy: 0.9383 - lr: 1.4901e-11
# Epoch 177/300
# 1204/1204 [==============================] - 12s 10ms/step - loss: 0.1842 - accuracy: 0.9393 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 1.4901e-11
# Epoch 178/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1841 - accuracy: 0.9391 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 7.4506e-12
# Epoch 179/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1840 - accuracy: 0.9391 - val_loss: 0.1852 - val_accuracy: 0.9386 - lr: 7.4506e-12
# Epoch 180/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1842 - accuracy: 0.9391 - val_loss: 0.1852 - val_accuracy: 0.9386 - lr: 7.4506e-12
# Epoch 181/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1839 - accuracy: 0.9395 - val_loss: 0.1851 - val_accuracy: 0.9388 - lr: 7.4506e-12
# Epoch 182/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1845 - accuracy: 0.9387 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 7.4506e-12
# Epoch 183/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1842 - accuracy: 0.9391 - val_loss: 0.1852 - val_accuracy: 0.9386 - lr: 3.7253e-12
# Epoch 184/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1840 - accuracy: 0.9392 - val_loss: 0.1851 - val_accuracy: 0.9387 - lr: 3.7253e-12
# Epoch 185/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1839 - accuracy: 0.9394 - val_loss: 0.1852 - val_accuracy: 0.9386 - lr: 3.7253e-12
# Epoch 186/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1842 - accuracy: 0.9389 - val_loss: 0.1853 - val_accuracy: 0.9385 - lr: 3.7253e-12
# Epoch 187/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1839 - accuracy: 0.9391 - val_loss: 0.1852 - val_accuracy: 0.9392 - lr: 3.7253e-12
# Epoch 188/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1839 - accuracy: 0.9393 - val_loss: 0.1853 - val_accuracy: 0.9386 - lr: 1.8626e-12
# Epoch 189/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1838 - accuracy: 0.9391 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 1.8626e-12
# Epoch 190/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1838 - accuracy: 0.9392 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 1.8626e-12
# Epoch 191/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1845 - accuracy: 0.9388 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 1.8626e-12
# Epoch 192/300
# 1204/1204 [==============================] - 13s 10ms/step - loss: 0.1838 - accuracy: 0.9394 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 1.8626e-12
# Epoch 193/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1837 - accuracy: 0.9395 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 9.3132e-13
# Epoch 194/300
# 1204/1204 [==============================] - 13s 10ms/step - loss: 0.1841 - accuracy: 0.9390 - val_loss: 0.1852 - val_accuracy: 0.9388 - lr: 9.3132e-13
# Epoch 195/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1843 - accuracy: 0.9393 - val_loss: 0.1852 - val_accuracy: 0.9389 - lr: 9.3132e-13
# Epoch 196/300
# 1204/1204 [==============================] - 14s 11ms/step - loss: 0.1839 - accuracy: 0.9390 - val_loss: 0.1851 - val_accuracy: 0.9384 - lr: 9.3132e-13
# Epoch 197/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1838 - accuracy: 0.9392 - val_loss: 0.1853 - val_accuracy: 0.9384 - lr: 9.3132e-13
# Epoch 198/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1837 - accuracy: 0.9390 - val_loss: 0.1853 - val_accuracy: 0.9385 - lr: 4.6566e-13
# Epoch 199/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1840 - accuracy: 0.9397 - val_loss: 0.1852 - val_accuracy: 0.9390 - lr: 4.6566e-13
# Epoch 200/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1845 - accuracy: 0.9390 - val_loss: 0.1852 - val_accuracy: 0.9386 - lr: 4.6566e-13
# Epoch 201/300
# 1204/1204 [==============================] - 14s 12ms/step - loss: 0.1840 - accuracy: 0.9390 - val_loss: 0.1852 - val_accuracy: 0.9382 - lr: 4.6566e-13
# Epoch 202/300
# 1204/1204 [==============================] - 14s 11ms/step - loss: 0.1845 - accuracy: 0.9390 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 4.6566e-13
# Epoch 203/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1841 - accuracy: 0.9386 - val_loss: 0.1852 - val_accuracy: 0.9390 - lr: 2.3283e-13
# Epoch 204/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1843 - accuracy: 0.9391 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 2.3283e-13
# Epoch 205/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1837 - accuracy: 0.9393 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 2.3283e-13
# Epoch 206/300
# 1204/1204 [==============================] - 14s 11ms/step - loss: 0.1842 - accuracy: 0.9395 - val_loss: 0.1852 - val_accuracy: 0.9386 - lr: 2.3283e-13
# Epoch 207/300
# 1204/1204 [==============================] - 14s 11ms/step - loss: 0.1837 - accuracy: 0.9391 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 2.3283e-13
# Epoch 208/300
# 1204/1204 [==============================] - 14s 11ms/step - loss: 0.1839 - accuracy: 0.9390 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 1.1642e-13
# Epoch 209/300
# 1204/1204 [==============================] - 14s 11ms/step - loss: 0.1842 - accuracy: 0.9392 - val_loss: 0.1852 - val_accuracy: 0.9386 - lr: 1.1642e-13
# Epoch 210/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1840 - accuracy: 0.9390 - val_loss: 0.1852 - val_accuracy: 0.9388 - lr: 1.1642e-13
# Epoch 211/300
# 1204/1204 [==============================] - 14s 11ms/step - loss: 0.1842 - accuracy: 0.9390 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 1.1642e-13
# Epoch 212/300
# 1204/1204 [==============================] - 14s 11ms/step - loss: 0.1838 - accuracy: 0.9395 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 1.1642e-13
# Epoch 213/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1842 - accuracy: 0.9392 - val_loss: 0.1852 - val_accuracy: 0.9388 - lr: 5.8208e-14
# Epoch 214/300
# 1204/1204 [==============================] - 14s 11ms/step - loss: 0.1839 - accuracy: 0.9390 - val_loss: 0.1852 - val_accuracy: 0.9386 - lr: 5.8208e-14
# Epoch 215/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1843 - accuracy: 0.9389 - val_loss: 0.1852 - val_accuracy: 0.9385 - lr: 5.8208e-14
# Epoch 216/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1843 - accuracy: 0.9392 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 5.8208e-14
# Epoch 217/300
# 1204/1204 [==============================] - 14s 11ms/step - loss: 0.1839 - accuracy: 0.9394 - val_loss: 0.1852 - val_accuracy: 0.9387 - lr: 5.8208e-14
# Epoch 218/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1841 - accuracy: 0.9391 - val_loss: 0.1852 - val_accuracy: 0.9388 - lr: 2.9104e-14
# Epoch 219/300
# 1204/1204 [==============================] - 13s 11ms/step - loss: 0.1845 - accuracy: 0.9388 - val_loss: 0.1853 - val_accuracy: 0.9382 - lr: 2.9104e-14
# Epoch 220/300
# 1204/1204 [==============================] - 14s 12ms/step - loss: 0.1840 - accuracy: 0.9390 - val_loss: 0.1852 - val_accuracy: 0.9386 - lr: 2.9104e-14
# Epoch 221/300
# 1204/1204 [==============================] - 14s 12ms/step - loss: 0.1843 - accuracy: 0.9390 - val_loss: 0.1852 - val_accuracy: 0.9386 - lr: 2.9104e-14
# ✅ Huấn luyện xong. Hiển thị biểu đồ...
# 🔎 Dự đoán trên tập test...
# 1376/1376 [==============================] - 4s 3ms/step
# 📊 Ma trận nhầm lẫn:
# 📋 Classification Report:
#                 precision    recall  f1-score   support
#
#         benign     0.9847    0.9663    0.9754      4000
#     bruteforce     0.9955    0.9952    0.9954      4000
#            dos     0.9594    0.8380    0.8946      4000
#            ftp     0.9962    0.9243    0.9589      4000
# reconnaissance     1.0000    0.9998    0.9999      4000
#  reverse_shell     0.9373    0.8445    0.8885      4000
#           smtp     0.9298    0.9968    0.9621      4001
#  sql_injection     0.8575    0.9540    0.9032      4000
#            ssh     0.9995    0.9998    0.9996      4000
#           ssrf     0.8834    0.8595    0.8713      4000
#            xss     0.8257    0.9573    0.8867      4000
#
#       accuracy                         0.9396     44001
#      macro avg     0.9426    0.9396    0.9396     44001
#   weighted avg     0.9426    0.9396    0.9396     44001
#
#
# 📈 ROC-AUC từng lớp:
# ✅ Test Accuracy: 0.9396 - Test Loss: 0.1855
# 💾 Mô hình đã được lưu vào: cnn_lstm_webids23_model.h5
